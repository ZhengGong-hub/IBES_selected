# %%
import pandas as pd 
import sys
## ---------- Define Root Path ---------- ## 
ROOTPATH = '/Users/zhenggong/Documents/Github/IBES_selected/' # for importing and reference management 
sys.path.append(ROOTPATH)

# %%
# price target 

# AMASKCD: the id of analysts, it remains the same across firms when they switch jobs
# ANNDATS, ANNTIMS: Date and Time when the estimate/ recommendation was released by an analyst
# ACTDATS, ACTTIMS: Date and Time when the estimate/ recommendation was entered into the database

pt = pd.read_csv('/Users/zhenggong/Documents/GitHub/IBES_selected/IBES_csv/mvu1wv7ytomyirk4.csv', index_col=[0])
# time cutoff
pt = pt.query("ANNDATS > '2008-01-01'").reset_index(drop=True)

# %%
# recommendataions (buy or sell or HOLD)

# Focus on IRECCD (which is reconciled at IBES level) 
# etext and ereccd are explicit recommendation (can be less comparable)
recommend = pd.read_csv('/Users/zhenggong/Documents/GitHub/IBES_selected/IBES_csv/nahghdromygr63ao.csv', index_col=[0])
# time cutoff
recommend = recommend.query("ANNDATS > '2008-01-01'").reset_index(drop=True)
recommend
# Out:
# /var/folders/0j/2k9yrkz575s8zxhdwtq0yrvm0000gn/T/ipykernel_8897/2792019095.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   recommend = pd.read_csv('/Users/zhenggong/Documents/GitHub/IBES_selected/IBES_csv/nahghdromygr63ao.csv', index_col=[0])
#         TICKER     CUSIP             CNAME OFTIC     ACTDATS   ESTIMID  \
# 0         0000  87482X10    TALMER BANCORP  TLMR  2014-03-10  RBCDOMIN
# 1         0000  87482X10    TALMER BANCORP  TLMR  2014-03-11  JPMORGAN
# 2         0000  87482X10    TALMER BANCORP  TLMR  2014-03-11     KEEFE
# 3         0000  87482X10    TALMER BANCORP  TLMR  2014-03-11   RAYMOND
# 4         0000  87482X10    TALMER BANCORP  TLMR  2014-03-11    STERNE
# ...        ...       ...               ...   ...         ...       ...
# 1652194    ZZZ  83125J10  SLEEP COUNTRY CA   ZZZ  2020-05-20  GRIFFMCB
# 1652195    ZZZ  83125J10  SLEEP COUNTRY CA   ZZZ  2020-12-07  GRIFFMCB
# 1652196    ZZZ  83125J10  SLEEP COUNTRY CA   ZZZ  2021-04-18  WOODGUND
# 1652197    ZZZ  83125J10  SLEEP COUNTRY CA   ZZZ  2021-11-15      TDSI
# 1652198    ZZZ  83125J10  SLEEP COUNTRY CA   ZZZ  2022-05-06      TDSI
#
#                  ANALYST ERECCD         ETEXT  IRECCD       ITEXT  EMASKCD  \
# 0        ARFSTROM      J      2    OUTPERFORM     2.0         BUY    659.0
# 1        ALEXOPOULOS   S    NaN    OVERWEIGHT     2.0         BUY   1243.0
# 2        MCGRATTY      C      2    OUTPERFORM     2.0         BUY   1308.0
# 3        LONG          D      1    STRONG BUY     1.0  STRONG BUY   1929.0
# 4        GREEN         P      2       NEUTRAL     3.0        HOLD   2209.0
# ...                  ...    ...           ...     ...         ...      ...
# 1652194    RESEARCH DEPA      2           BUY     2.0         BUY   2840.0
# 1652195  LANDRY        M      2           BUY     2.0         BUY   2840.0
# 1652196  ZAMPARO       J      1  OUTPERFORMER     2.0         BUY   1750.0
# 0         119962.0    NaN   D   1  ...  1960-01-01 15:17:12.000  2014-03-09
# 1          80474.0    NaN   D   1  ...  1960-01-01 15:49:22.000  2014-03-10
# 2          50789.0    NaN   D   1  ...  1960-01-01 15:22:08.000  2014-03-10
# 3          79092.0    NaN   D   1  ...  1960-01-01 17:10:49.999  2014-03-10
# 4          71182.0    NaN   D   1  ...  1960-01-01 02:27:00.000  2014-03-17
# ...            ...    ...  ..  ..  ...                      ...         ...
# 50198619  122730.0    NaN   D   5  ...  1960-01-01 02:29:24.000  2022-02-18
# 50198620  191632.0    NaN   D   4  ...  1960-01-01 03:50:42.000  2023-10-15
# 50198621  191632.0    NaN   D   4  ...  1960-01-01 14:29:19.000  2023-10-26
# 50198622  191632.0    NaN   D   5  ...  1960-01-01 03:50:47.000  2023-10-15
# 50198623  191632.0    NaN   D   5  ...  1960-01-01 14:29:18.000  2023-10-26
#
#                       ANNTIMS  ACTUAL ACTDATS_ACT              ACTTIMS_ACT  \
# 0         1960-01-01 17:05:00    1.21  2015-01-30  1960-01-01 16:54:47.000
# 1         1960-01-01 06:48:00    1.21  2015-01-30  1960-01-01 16:54:47.000
# 2         1960-01-01 07:45:00    1.21  2015-01-30  1960-01-01 16:54:47.000
# 3         1960-01-01 00:25:00    1.21  2015-01-30  1960-01-01 16:54:47.000
# 4         1960-01-01 20:05:00    1.21  2015-01-30  1960-01-01 16:54:47.000
# ...                       ...     ...         ...                      ...
# 50198619  1960-01-01 14:03:00     NaN         NaN                      NaN
# 50198620  1960-01-01 17:01:00     NaN         NaN                      NaN
# 50198621  1960-01-01 22:27:00     NaN         NaN                      NaN
# 50198622  1960-01-01 17:01:00     NaN         NaN                      NaN
# 50198623  1960-01-01 22:27:00     NaN         NaN                      NaN
#
#          ANNDATS_ACT          ANNTIMS_ACT CURR_ACT report_curr
# 0         2015-01-30  1960-01-01 16:30:00      USD         USD
# 1         2015-01-30  1960-01-01 16:30:00      USD         USD
# 2         2015-01-30  1960-01-01 16:30:00      USD         USD
# 3         2015-01-30  1960-01-01 16:30:00      USD         USD
# 4         2015-01-30  1960-01-01 16:30:00      USD         USD
# ...              ...                  ...      ...         ...
# 50198619         NaN                  NaN      NaN         USD
# 50198620         NaN                  NaN      NaN         USD
# 50198621         NaN                  NaN      NaN         USD
# 50198622         NaN                  NaN      NaN         USD
# 50198623         NaN                  NaN      NaN         USD
#
# [50198624 rows x 27 columns]

# %%
# what is this?
df = pd.read_csv('/Users/zhenggong/Documents/GitHub/IBES_selected/IBES_csv/ueqdv2nsit9f644y.csv', index_col=[0])
df
# Out:
# /var/folders/0j/2k9yrkz575s8zxhdwtq0yrvm0000gn/T/ipykernel_13050/418178164.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/zhenggong/Documents/GitHub/IBES_selected/IBES_csv/ueqdv2nsit9f644y.csv', index_col=[0])
#        TICKER     CUSIP             CNAME   OFTIC HMKTCD MSCIPF  USFIRM  \
# 0        0000       NaN    TALMER BANCORP  IPO-TL    NaN    NaN     1.0
# 1        0000  87482X10    TALMER BANCORP    TLMR   TLMR    NaN     1.0
# 2        0000  87482X10    TALMER BANCORP    TLMR   TLMR    NaN     1.0
# 3        0000  87482X10    TALMER BANCORP    TLMR   TLMR    0.0     1.0
# 4        0001  26878510         EP ENERGY     EPE    EPE    NaN     1.0
# ...       ...       ...               ...     ...    ...    ...     ...
# 484082    ZZZ  83125J10  SLEEP COUNTRY CA     ZZZ    ZZZ    0.0     0.0
# 484083   ZZZ1  Q2261V10      CHALICE GOLD     CXN    CXN    NaN     0.0
# 484084   ZZZ1  Q2261V10      CHALICE GOLD     CXN    CXN    0.0     0.0
# 484085   ZZZ1  Q2261V10    CHALICE MINING     CXN    CXN    NaN     0.0
# 484086   ZZZ1  Q2261V10    CHALICE MINING     CXN    CXN    NaN     0.0
#
#             SDATES      EDATES
# 0       2014-02-08  2014-02-12
# 1       2014-02-12  2014-03-10
# 2       2014-03-10  2014-05-12
# 3       2014-05-12         NaN
# 4       2014-02-08  2014-02-26
# ...            ...         ...
# 484082  2017-07-31         NaN
# 484083  2011-08-11  2014-01-13
# 484084  2014-01-13  2020-12-10
# 484085  2020-12-10  2021-11-01
# 484086  2021-11-01         NaN
#
# [484087 rows x 9 columns]

# %%
pt['ANNTIMS'] = pd.to_datetime(pt['ANNTIMS'], format="mixed").dt.time
pt['ACTTIMS'] = pd.to_datetime(pt['ACTTIMS'], format="mixed").dt.time
# Out:
#         TICKER     CUSIP OFTIC             CNAME     ACTDATS   ESTIMID  \
# 0         0000  87482X10  TLMR    TALMER BANCORP  2014-03-10  RBCDOMIN
# 1         0000  87482X10  TLMR    TALMER BANCORP  2014-03-11     KEEFE
# 2         0000  87482X10  TLMR    TALMER BANCORP  2014-03-11  JPMORGAN
# 3         0000  87482X10  TLMR    TALMER BANCORP  2014-03-11   RAYMOND
# 4         0000  87482X10  TLMR    TALMER BANCORP  2014-04-08  JPMORGAN
# ...        ...       ...   ...               ...         ...       ...
# 5682983    ZZZ  83125J10   ZZZ  SLEEP COUNTRY CA  2023-10-04      TDSI
# 5682984    ZZZ  83125J10   ZZZ  SLEEP COUNTRY CA  2023-11-10     BURNS
# 5682985    ZZZ  83125J10   ZZZ  SLEEP COUNTRY CA  2023-11-10  WOODGUND
# 5682986    ZZZ  83125J10   ZZZ  SLEEP COUNTRY CA  2023-11-14  RBCDOMIN
# 5682987    ZZZ  83125J10   ZZZ  SLEEP COUNTRY CA  2024-02-05  LEVESQUE
#
#                       ALYSNAM  HORIZON  VALUE ESTCUR CURR   AMASKCD  USFIRM  \
# 0        ARFSTROM           J       12   16.0    USD  USD   71182.0     1.0
# 1        MCGRATTY           C       12   16.0    USD  USD  119962.0     1.0
# 2        ALEXOPOULOS        S       12   16.0    USD  USD   79092.0     1.0
# 3        LONG               D       12   16.0    USD  USD   80474.0     1.0
# 4        ALEXOPOULOS        S       12   16.5    USD  USD   79092.0     1.0
# ...                       ...      ...    ...    ...  ...       ...     ...
# 5682983  MORRISON           B       12   29.0    CAD  CAD   81327.0     0.0
# 5682984  MACLEOD            S       12   28.0    CAD  CAD  126686.0     0.0
# 5682985  ZAMPARO            J       12   27.0    CAD  CAD  165585.0     0.0
# 5682986  KHAN               S       12   24.0    CAD  CAD  164837.0     0.0
# 5682987  SHREEDHAR          V       12   28.0    CAD  CAD  122543.0     0.0
#
#                  ACTTIMS     ANNDATS   ANNTIMS
# 0        08:54:02.999000  2014-03-10  00:20:00
# 1               15:17:15  2014-03-09  17:05:00
# 2               17:10:47  2014-03-10  00:25:00
# 3               15:49:22  2014-03-10  06:48:00
# 4               08:55:39  2014-04-07  00:24:00
# ...                  ...         ...       ...
# 5682983         06:44:40  2023-10-04  06:37:00
# 5682984         13:30:16  2023-11-10  13:20:00
# 5682985         14:19:03  2023-11-10  14:10:00
# 5682986         21:27:33  2023-11-14  21:18:00
# 5682987         20:17:00  2024-02-05  20:05:00
#
# [5682988 rows x 16 columns]

# %%
recommend['ANNTIMS'] = pd.to_datetime(recommend['ANNTIMS'], format="mixed").dt.time
recommend['ACTTIMS'] = pd.to_datetime(recommend['ACTTIMS'], format="mixed").dt.time

# %%
act['ANNTIMS'] = pd.to_datetime(act['ANNTIMS'], format="mixed").dt.time
act['ACTTIMS'] = pd.to_datetime(act['ACTTIMS'], format="mixed").dt.time

# %%
act = act.query("ANNDATS > '2008-01-01'").reset_index(drop=True)
act = act.drop(columns=['PDF', 'CURRFL'])
act = act.query("CURR_ACT == 'USD'").reset_index(drop=True) # US firm
act = act.query("report_curr == 'USD'").reset_index(drop=True) # US firm
act = act.drop(columns=['report_curr', 'CURR_ACT'])
act
# Out:
#          TICKER     CUSIP OFTIC           CNAME     ACTDATS  ESTIMATOR  \
# 0          0000  87482X10  TLMR  TALMER BANCORP  2014-03-11      149.0
# 1          0000  87482X10  TLMR  TALMER BANCORP  2014-03-11      228.0
# 2          0000  87482X10  TLMR  TALMER BANCORP  2014-03-11      952.0
# 3          0000  87482X10  TLMR  TALMER BANCORP  2014-03-11      873.0
# 4          0000  87482X10  TLMR  TALMER BANCORP  2014-03-17     1267.0
# ...         ...       ...   ...             ...         ...        ...
# 30290383   ZYNX  98986M10  ZYXI       ZYNEX INC  2020-10-12     2709.0
# 30290384   ZYNX  98986M10  ZYXI       ZYNEX INC  2020-10-27      220.0
# 30290385   ZYNX  98986M10  ZYXI       ZYNEX INC  2021-01-13     2342.0
# 30290386   ZYNX  98986M10  ZYXI       ZYNEX INC  2019-09-23      926.0
# 30290387   ZYNX  98986M10  ZYXI       ZYNEX INC  2020-02-25     2709.0
#
#             ANALYS FPI MEASURE    VALUE  ...                  ACTTIMS  \
# 0         119962.0   1     EPS    0.730  ...  1960-01-01 15:17:12.000
# 1          80474.0   1     EPS    0.830  ...  1960-01-01 15:49:22.000
# 2          50789.0   1     EPS    0.660  ...  1960-01-01 15:22:08.000
# 3          79092.0   1     EPS    0.800  ...  1960-01-01 17:10:49.999
# 4          71182.0   1     EPS    0.860  ...  1960-01-01 20:13:35.000
# ...            ...  ..     ...      ...  ...                      ...
# 30290383  122730.0   3     SAL  206.250  ...  1960-01-01 12:14:03.000
# 30290384  138585.0   3     SAL  208.589  ...  1960-01-01 20:49:27.000
# 30290385   53136.0   3     SAL  155.000  ...  1960-01-01 08:59:54.999
# 30290386  118308.0   4     SAL   93.400  ...  1960-01-01 07:45:17.000
# 4         2015-01-30  1960-01-01 16:30:00
# ...              ...                  ...
# 30290383  2023-03-13  1960-01-01 08:00:00
# 30290384  2023-03-13  1960-01-01 08:00:00
# 30290385  2023-03-13  1960-01-01 08:00:00
# 30290386  2023-03-13  1960-01-01 08:00:00
# 30290387  2023-03-13  1960-01-01 08:00:00
#
# [30290388 rows x 22 columns]

# %%
# us firm only
try:
    pt = pt.query("USFIRM == 1.0 and ESTCUR == 'USD' and CURR == 'USD'").reset_index(drop=True) # US firm
    pt = pt.drop(columns=['CURR', 'ESTCUR', 'USFIRM'])
except:
    print('try part not successful')
pt
# Out:
# try part not successful
#         TICKER     CUSIP OFTIC           CNAME     ACTDATS   ESTIMID  \
# 0         0000  87482X10  TLMR  TALMER BANCORP  2014-03-10  RBCDOMIN
# 1         0000  87482X10  TLMR  TALMER BANCORP  2014-03-11     KEEFE
# 2         0000  87482X10  TLMR  TALMER BANCORP  2014-03-11  JPMORGAN
# 3         0000  87482X10  TLMR  TALMER BANCORP  2014-03-11   RAYMOND
# 4         0000  87482X10  TLMR  TALMER BANCORP  2014-04-08  JPMORGAN
# ...        ...       ...   ...             ...         ...       ...
# 1660547   ZYNX  98986M10  ZYXI           ZYNEX  2023-03-14  LADENBUR
# 1660548   ZYNX  98986M10  ZYXI           ZYNEX  2023-03-28  LADENBUR
# 1660549   ZYNX  98986M10  ZYXI           ZYNEX  2023-10-15  RBCDOMIN
# 1660550   ZYNX  98986M10  ZYXI           ZYNEX  2023-10-27  LADENBUR
# 1660551   ZYNX  98986M10  ZYXI           ZYNEX  2023-11-03  EQUISIGH
#
#                       ALYSNAM  HORIZON  VALUE   AMASKCD          ACTTIMS  \
# 0        ARFSTROM           J       12   16.0   71182.0  08:54:02.999000
# 1        MCGRATTY           C       12   16.0  119962.0         15:17:15
# 2        ALEXOPOULOS        S       12   16.0   79092.0         17:10:47
# 3        LONG               D       12   16.0   80474.0         15:49:22
# 4        ALEXOPOULOS        S       12   16.5   79092.0         08:55:39
# ...                       ...      ...    ...       ...              ...
# 1660547  COHEN              J       12   27.0  122730.0         10:32:14
# 1660548  COHEN              J       12   28.0  122730.0         06:39:15
# 1660549  SINGH              S       12   13.0  191632.0         22:47:54
# 1660550  COHEN              J       12   27.0  122730.0         06:46:41
# 1660551  TALSANIA           P       12   16.5  200938.0         05:59:33
#
#             ANNDATS   ANNTIMS
# 0        2014-03-10  00:20:00
# 1        2014-03-09  17:05:00
# 2        2014-03-10  00:25:00
# 3        2014-03-10  06:48:00
# 4        2014-04-07  00:24:00
# ...             ...       ...
# 1660547  2023-03-14  10:30:00
# 1660548  2023-03-28  06:33:00
# 1660549  2023-10-15  17:01:00
# 1660550  2023-10-27  06:33:00
# 1660551  2023-11-03  03:47:00
#
# [1660552 rows x 13 columns]

# %%
# us firm only
try:
    recommend = recommend.query("USFIRM == 1.0").reset_index(drop=True) # US firm
    recommend = recommend.drop(columns=['USFIRM'])
except:
    print('try part not successful')

try:
    recommend = recommend.drop(columns=['ITEXT', 'IRECCD'])
except:
# 386021  2021-07-16  1960-01-01 02:32:00
# 386022  2023-01-06  1960-01-01 03:39:00
# 386023  2023-10-15  1960-01-01 17:01:00
# 386024  2023-11-03  1960-01-01 03:47:00
#
# [386025 rows x 16 columns]

# %%
pt.query("TICKER == 'AAPL'")
# Out:
#       TICKER     CUSIP OFTIC      CNAME     ACTDATS   ESTIMID  \
# 85823   AAPL  03783310  AAPL  APPLE INC  2008-01-03   NEEDHAM
# 85824   AAPL  03783310  AAPL  APPLE INC  2008-01-04   GOLDMAN
# 85825   AAPL  03783310  AAPL  APPLE INC  2008-01-07    MORGAN
# 85826   AAPL  03783310  AAPL  APPLE INC  2008-01-08       GKM
# 85827   AAPL  03783310  AAPL  APPLE INC  2008-01-11      BERN
# ...      ...       ...   ...        ...         ...       ...
# 88702   AAPL  03783310  AAPL      APPLE  2024-02-02    MELIUS
# 88703   AAPL  03783310  AAPL      APPLE  2024-02-02   MONNESS
# 88704   AAPL  03783310  AAPL      APPLE  2024-02-05  EQUISIGH
# 88705   AAPL  03783310  AAPL      APPLE  2024-02-05  LOOPCAMA
# 88706   AAPL  03783310  AAPL      APPLE  2024-02-07  DAVIDSON
#
#                     ALYSNAM  HORIZON    VALUE   AMASKCD   ACTTIMS     ANNDATS  \
# 85823  WOLF               C       12    8.393    1047.0  12:24:42  2008-01-03
# 85824  BAILEY             D       12    7.857   70648.0  12:02:02  2008-01-03
# 85825  HUBERTY            K       12    7.321   86702.0  04:32:36  2008-01-07
# 85826  BACHMAN            K       12    7.321   70706.0  10:13:22  2008-01-08
# 85827  SACCONAGHI         T       12    5.893   58377.0  03:48:01  2008-01-11
# ...                     ...      ...      ...       ...       ...         ...
# 88702  REITZES            B       24  220.000   49595.0  06:46:04  2024-02-02
# 88703  WHITE              B       12  200.000   78750.0  07:55:12  2024-02-02
# 88704  TALSANIA           P       12  206.860  200938.0  10:38:51  2024-02-05
# 88705  BARUAH             A       12  185.000  119509.0  05:55:52  2024-02-05
# 88706  LURIA              G       12  200.000  115953.0  06:53:54  2024-02-07
#
#         ANNTIMS
# 85823  08:37:00
# 85824  20:30:00
# 85825  04:24:00
# 85826  08:30:00
# 85827  03:20:00
# ...         ...
# 88702  06:00:00
# 88703  07:54:00
# 88704  09:57:00
# 88705  05:50:00
# 88706  06:35:00
#
# [2884 rows x 13 columns]

# %%
recommend.query("TICKER == 'AAPL'")
# Out:
#       TICKER     CUSIP      CNAME OFTIC     ACTDATS   ESTIMID  \
# 20203   AAPL  03783310  APPLE INC  AAPL  2008-01-03   NEEDHAM
# 20204   AAPL  03783310  APPLE INC  AAPL  2008-01-23   NEEDHAM
# 20205   AAPL  03783310  APPLE INC  AAPL  2008-01-23   CARISCO
# 20206   AAPL  03783310  APPLE INC  AAPL  2008-01-23  KINTISHE
# 20207   AAPL  03783310  APPLE INC  AAPL  2008-02-04    DOLMEN
# ...      ...       ...        ...   ...         ...       ...
# 20624   AAPL  03783310      APPLE  AAPL  2024-01-02  FRCLAYSC
# 20625   AAPL  03783310      APPLE  AAPL  2024-01-04     PIPER
# 20626   AAPL  03783310      APPLE  AAPL  2024-01-12   REDBURN
# 20627   AAPL  03783310      APPLE  AAPL  2024-01-18   MERRILL
# 20628   AAPL  03783310      APPLE  AAPL  2024-02-05  EQUISIGH
#
#                ANALYST ERECCD          ETEXT  EMASKCD   AMASKCD  \
# 20203  WOLF          C      2            BUY   1648.0    1047.0
# 20204  WOLF          C      1     STRONG BUY   1648.0    1047.0
# 20205  SEYRAFI       S      2  ABOVE AVERAGE   5253.0   58063.0
# 20206  KINTISHEFF    T    NaN           HOLD   5697.0   89770.0
# 20207  TAYLOR        S    NaN            BUY   4724.0  121952.0
# ...                ...    ...            ...      ...       ...
# 20624  LONG          T      4    UNDERWEIGHT  10902.0   49552.0
# 20625  KUMAR         H      3        NEUTRAL   1859.0   72469.0
# 20626  CORDWELL      J      2        NEUTRAL   6706.0  125796.0
# 20627  MOHAN         W      1            BUY   1534.0  125669.0
# 20628  TALSANIA      P      2     OUTPERFORM  41830.0  200938.0
#
#                        ACTTIMS     REVDATS                  REVTIMS  \
# 20203  1960-01-01 12:24:42.000  2008-01-03  1960-01-01 12:24:42.000
# 20204  1960-01-01 09:53:39.000  2009-10-20  1960-01-01 07:44:38.000
# 20205  1960-01-01 09:54:50.000  2008-07-14  1960-01-01 11:02:57.000
# 20206  1960-01-01 08:31:20.000  2008-01-23  1960-01-01 08:31:20.000
# 20207  1960-01-01 05:28:55.000  2008-02-04  1960-01-01 05:28:55.000
# ...                        ...         ...                      ...
# 20624  1960-01-01 00:25:01.000  2024-02-08  1960-01-01 01:23:53.000
# 20625  1960-01-01 04:11:06.000  2024-02-01  1960-01-01 22:04:16.000
# 20626  1960-01-01 16:13:46.000  2024-02-09  1960-01-01 05:52:58.000
# 20627  1960-01-01 06:09:02.000  2024-02-14  1960-01-01 23:19:34.000
# 20628  1960-01-01 10:38:51.000  2024-02-05  1960-01-01 10:38:51.000
#
#           ANNDATS                  ANNTIMS
# 20203  2008-01-03  1960-01-01 08:37:00.000
# 20204  2008-01-23  1960-01-01 08:26:00.000
# 20205  2008-01-23  1960-01-01 08:01:00.000
# 20206  2008-01-23  1960-01-01 06:11:00.000
# 20207  2008-02-01  1960-01-01 08:59:00.000
# ...           ...                      ...
# 20624  2024-01-02  1960-01-01 00:12:00.000
# 20625  2024-01-04  1960-01-01 03:30:00.000
# 20626  2024-01-12  1960-01-01 15:57:00.000
# 20627  2024-01-18  1960-01-01 06:07:00.000
# 20628  2024-02-05  1960-01-01 09:57:00.000
#
# [426 rows x 16 columns]

# %%
num_distinct_analysis = len(pt['AMASKCD'].unique())
num_distinct_companies = len(pt['CUSIP'].unique())
num_of_records = len(pt)

print('some selective statistics:')
print('-----------------------')
print('number of records: ' + str(num_of_records))
print('the number of distinct analysts: ' + str(num_distinct_analysis))
print('the number of distinct companies: ' + str(num_distinct_companies))
print('the number of distinct target-pricing firm: ' + str(len(pt['ESTIMID'].unique())))
print('per company the average number of target price posing: ' + str(int(num_of_records/num_distinct_companies)))

#####################################################

num_distinct_analysis = len(recommend['AMASKCD'].unique())
num_distinct_companies = len(recommend['CUSIP'].unique())
num_of_records = len(recommend)

print('some selective statistics:')
print('-----------------------')
print('number of records: ' + str(num_of_records))
print('the number of distinct analysts: ' + str(num_distinct_analysis))
print('the number of distinct companies: ' + str(num_distinct_companies))
print('the number of distinct target-pricing firm: ' + str(len(pt['ESTIMID'].unique())))
print('per company the average number of target price posing: ' + str(int(num_of_records/num_distinct_companies)))
# Out:
# some selective statistics:
# -----------------------
# number of records: 1660552
# the number of distinct analysts: 10986
# the number of distinct companies: 12103
# the number of distinct target-pricing firm: 782
# per company the average number of target price posing: 137
# some selective statistics:
# -----------------------
# number of records: 386025
# the number of distinct analysts: 11661
# the number of distinct companies: 12828
# the number of distinct target-pricing firm: 782
# per company the average number of target price posing: 30

# %%
# get list of all analysts 
# group by
grouped = pt.groupby(by=['AMASKCD', 'ALYSNAM', 'ESTIMID']).count()
grouped
# Out:
#                                         TICKER  CUSIP  OFTIC  CNAME  ACTDATS  \
# AMASKCD  ALYSNAM              ESTIMID
# 26.0     ZIEGLER            J JMDUTTON       3      3      3      3        3
# 29.0     SMITH              K HAYWOOD        4      4      4      4        4
# 70.0     FRANCE             J AMERTECH      40     39     39     39       40
#                               CANTORFZ     356    356    356    356      356
#                               GHUNTER       23     23     23     23       23
# ...                                        ...    ...    ...    ...      ...
# 201808.0 HAYWOOD            C MERRILL        1      1      1      1        1
# 201823.0 LA ROSA            J LEERINK        1      1      1      1        1
# 201838.0 KO                 M LUCKY          1      1      1      1        1
# 201849.0 FLYNN              J POINT          1      1      1      1        1
# 201871.0 KENNEDY            S MIZUSEC        1      1      1      1        1
#
#                                         HORIZON  VALUE  ACTTIMS  ANNDATS  \
# AMASKCD  ALYSNAM              ESTIMID
# 26.0     ZIEGLER            J JMDUTTON        3      3        3        3
# 29.0     SMITH              K HAYWOOD         4      4        4        4
# 70.0     FRANCE             J AMERTECH       40     40       40       40
#                               CANTORFZ      356    356      356      356
#                               GHUNTER        23     23       23       23
# ...                                         ...    ...      ...      ...
# 201808.0 HAYWOOD            C MERRILL         1      1        1        1
# 201823.0 LA ROSA            J LEERINK         1      1        1        1
# 201838.0 KO                 M LUCKY           1      1        1        1
# 201849.0 FLYNN              J POINT           1      1        1        1
# 201871.0 KENNEDY            S MIZUSEC         1      1        1        1
#
#                                         ANNTIMS
# AMASKCD  ALYSNAM              ESTIMID
# 26.0     ZIEGLER            J JMDUTTON        3
# 29.0     SMITH              K HAYWOOD         4
# 70.0     FRANCE             J AMERTECH       40
#                               CANTORFZ      356
#                               GHUNTER        23
# ...                                         ...
# 201808.0 HAYWOOD            C MERRILL         1
# 201823.0 LA ROSA            J LEERINK         1
# 201838.0 KO                 M LUCKY           1
# 201849.0 FLYNN              J POINT           1
# 201871.0 KENNEDY            S MIZUSEC         1
#
# [16657 rows x 10 columns]

# %%
pt.to_parquet('price_target.parquet')
pt.to_csv('price_target.csv')

# %%
recommend.to_parquet('recommendation.parquet')
recommend.to_csv('recommendation.csv')

# %%
act.to_csv('estimate.csv')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
